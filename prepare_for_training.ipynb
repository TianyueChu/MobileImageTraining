# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (4.25.5)
# Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 32.0 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.17.0

# %%
# !pip install onnxruntime-training
# Out:
# Collecting onnxruntime-training
#   Downloading onnxruntime_training-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting cerberus (from onnxruntime-training)
#   Downloading Cerberus-1.3.5-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (24.3.25)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (3.12.1)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (1.26.4)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (1.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (1.13.1)
# Requirement already satisfied: setuptools>=61.0.0 in /usr/local/lib/python3.10/dist-packages (from onnxruntime-training) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime-training) (1.3.0)
# Downloading onnxruntime_training-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (299.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 MB 4.0 MB/s eta 0:00:00
# Downloading Cerberus-1.3.5-py3-none-any.whl (30 kB)
# Installing collected packages: cerberus, onnxruntime-training
# Successfully installed cerberus-1.3.5 onnxruntime-training-1.19.2

# %%
import torch
import torchvision
import onnx # Import onnx
import os
from torchvision import models
import torch.nn as nn
from torchvision.models import MobileNet_V2_Weights

# %%
class CelebAMobileNet(nn.Module):
    """
    A custom MobileNetV2 model for the CelebA dataset with a frozen feature extractor
    and a customizable classifier head.

    Args:
        num_classes (int): The number of output classes for the classifier head.
    """

    def __init__(self, num_classes=4):
        super(CelebAMobileNet, self).__init__()

        # Load the pre-trained MobileNetV2 model
        self.model = models.mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V2)

        # Freeze the feature extractor
        for param in self.model.features.parameters():
            param.requires_grad = False

        # Replace the classifier head with a new fully connected layer
        self.model.classifier[1] = nn.Linear(self.model.last_channel, num_classes)

        # Initialize the new classifier head
        self._initialize_classifier()

    def _initialize_classifier(self):
        """Initialize the classifier head parameters."""
        nn.init.kaiming_uniform_(self.model.classifier[1].weight)
        nn.init.zeros_(self.model.classifier[1].bias)

    def forward(self, x):
        """
        Forward pass for the model.

        Args:
            x (torch.Tensor): Input tensor of shape [batch_size, channels, height, width].

        Returns:
            torch.Tensor: Output tensor of shape [batch_size, num_classes].
        """
        return self.model(x)

# %%
model = CelebAMobileNet(num_classes=4)

# Load the state dictionary with weights_only=True
state_dict = torch.load('/content/model_state_dict.pth', map_location=torch.device('cpu'), weights_only=True)

# Load the state dictionary into the model
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
# Export the model to ONNX.
model_name = "mobilenetv2"
# Create the 'training_artifacts' directory if it doesn't exist
os.makedirs("training_artifacts", exist_ok=True)
torch.onnx.export(model, torch.randn(1, 3, 224, 224),
                  f"training_artifacts/{model_name}.onnx",
                  input_names=["input"], output_names=["output"],
                  dynamic_axes={"input": {0: "batch"}, "output": {0: "batch"}})

# %%
from onnxruntime.training import artifacts

# Load the onnx model.
onnx_model = onnx.load(f"training_artifacts/{model_name}.onnx")

# %%
for node in onnx_model.graph.node:
    # Print the node's name and its input names directly
    print(node.name, node.input)
# Out:
# /model/features/features.0/features.0.0/Conv ['input', 'onnx::Conv_538', 'onnx::Conv_539']
# /model/features/features.0/features.0.2/Constant []
# /model/features/features.0/features.0.2/Constant_1 []
# /model/features/features.0/features.0.2/Clip ['/model/features/features.0/features.0.0/Conv_output_0', '/model/features/features.0/features.0.2/Constant_output_0', '/model/features/features.0/features.0.2/Constant_1_output_0']
# /model/features/features.1/conv/conv.0/conv.0.0/Conv ['/model/features/features.0/features.0.2/Clip_output_0', 'onnx::Conv_541', 'onnx::Conv_542']
# /model/features/features.1/conv/conv.0/conv.0.2/Constant []
# /model/features/features.1/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.1/conv/conv.0/conv.0.2/Clip ['/model/features/features.1/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.1/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.1/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.1/conv/conv.1/Conv ['/model/features/features.1/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_544', 'onnx::Conv_545']
# /model/features/features.2/conv/conv.0/conv.0.0/Conv ['/model/features/features.1/conv/conv.1/Conv_output_0', 'onnx::Conv_547', 'onnx::Conv_548']
# /model/features/features.2/conv/conv.0/conv.0.2/Constant []
# /model/features/features.2/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.2/conv/conv.0/conv.0.2/Clip ['/model/features/features.2/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.2/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.2/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.2/conv/conv.1/conv.1.0/Conv ['/model/features/features.2/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_550', 'onnx::Conv_551']
# /model/features/features.2/conv/conv.1/conv.1.2/Constant []
# /model/features/features.2/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.2/conv/conv.1/conv.1.2/Clip ['/model/features/features.2/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.2/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.2/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.2/conv/conv.2/Conv ['/model/features/features.2/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_553', 'onnx::Conv_554']
# /model/features/features.3/conv/conv.0/conv.0.0/Conv ['/model/features/features.2/conv/conv.2/Conv_output_0', 'onnx::Conv_556', 'onnx::Conv_557']
# /model/features/features.3/conv/conv.0/conv.0.2/Constant []
# /model/features/features.3/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.3/conv/conv.0/conv.0.2/Clip ['/model/features/features.3/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.3/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.3/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.3/conv/conv.1/conv.1.0/Conv ['/model/features/features.3/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_559', 'onnx::Conv_560']
# /model/features/features.3/conv/conv.1/conv.1.2/Constant []
# /model/features/features.3/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.3/conv/conv.1/conv.1.2/Clip ['/model/features/features.3/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.3/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.3/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.3/conv/conv.2/Conv ['/model/features/features.3/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_562', 'onnx::Conv_563']
# /model/features/features.3/Add ['/model/features/features.2/conv/conv.2/Conv_output_0', '/model/features/features.3/conv/conv.2/Conv_output_0']
# /model/features/features.4/conv/conv.0/conv.0.0/Conv ['/model/features/features.3/Add_output_0', 'onnx::Conv_565', 'onnx::Conv_566']
# /model/features/features.4/conv/conv.0/conv.0.2/Constant []
# /model/features/features.4/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.4/conv/conv.0/conv.0.2/Clip ['/model/features/features.4/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.4/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.4/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.4/conv/conv.1/conv.1.0/Conv ['/model/features/features.4/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_568', 'onnx::Conv_569']
# /model/features/features.4/conv/conv.1/conv.1.2/Constant []
# /model/features/features.4/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.4/conv/conv.1/conv.1.2/Clip ['/model/features/features.4/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.4/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.4/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.4/conv/conv.2/Conv ['/model/features/features.4/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_571', 'onnx::Conv_572']
# /model/features/features.5/conv/conv.0/conv.0.0/Conv ['/model/features/features.4/conv/conv.2/Conv_output_0', 'onnx::Conv_574', 'onnx::Conv_575']
# /model/features/features.5/conv/conv.0/conv.0.2/Constant []
# /model/features/features.5/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.5/conv/conv.0/conv.0.2/Clip ['/model/features/features.5/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.5/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.5/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.5/conv/conv.1/conv.1.0/Conv ['/model/features/features.5/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_577', 'onnx::Conv_578']
# /model/features/features.5/conv/conv.1/conv.1.2/Constant []
# /model/features/features.5/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.5/conv/conv.1/conv.1.2/Clip ['/model/features/features.5/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.5/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.5/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.5/conv/conv.2/Conv ['/model/features/features.5/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_580', 'onnx::Conv_581']
# /model/features/features.5/Add ['/model/features/features.4/conv/conv.2/Conv_output_0', '/model/features/features.5/conv/conv.2/Conv_output_0']
# /model/features/features.6/conv/conv.0/conv.0.0/Conv ['/model/features/features.5/Add_output_0', 'onnx::Conv_583', 'onnx::Conv_584']
# /model/features/features.6/conv/conv.0/conv.0.2/Constant []
# /model/features/features.6/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.6/conv/conv.0/conv.0.2/Clip ['/model/features/features.6/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.6/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.6/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.6/conv/conv.1/conv.1.0/Conv ['/model/features/features.6/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_586', 'onnx::Conv_587']
# /model/features/features.6/conv/conv.1/conv.1.2/Constant []
# /model/features/features.6/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.6/conv/conv.1/conv.1.2/Clip ['/model/features/features.6/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.6/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.6/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.6/conv/conv.2/Conv ['/model/features/features.6/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_589', 'onnx::Conv_590']
# /model/features/features.6/Add ['/model/features/features.5/Add_output_0', '/model/features/features.6/conv/conv.2/Conv_output_0']
# /model/features/features.7/conv/conv.0/conv.0.0/Conv ['/model/features/features.6/Add_output_0', 'onnx::Conv_592', 'onnx::Conv_593']
# /model/features/features.7/conv/conv.0/conv.0.2/Constant []
# /model/features/features.7/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.7/conv/conv.0/conv.0.2/Clip ['/model/features/features.7/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.7/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.7/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.7/conv/conv.1/conv.1.0/Conv ['/model/features/features.7/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_595', 'onnx::Conv_596']
# /model/features/features.7/conv/conv.1/conv.1.2/Constant []
# /model/features/features.7/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.7/conv/conv.1/conv.1.2/Clip ['/model/features/features.7/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.7/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.7/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.7/conv/conv.2/Conv ['/model/features/features.7/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_598', 'onnx::Conv_599']
# /model/features/features.8/conv/conv.0/conv.0.0/Conv ['/model/features/features.7/conv/conv.2/Conv_output_0', 'onnx::Conv_601', 'onnx::Conv_602']
# /model/features/features.8/conv/conv.0/conv.0.2/Constant []
# /model/features/features.8/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.8/conv/conv.0/conv.0.2/Clip ['/model/features/features.8/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.8/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.8/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.8/conv/conv.1/conv.1.0/Conv ['/model/features/features.8/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_604', 'onnx::Conv_605']
# /model/features/features.8/conv/conv.1/conv.1.2/Constant []
# /model/features/features.8/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.8/conv/conv.1/conv.1.2/Clip ['/model/features/features.8/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.8/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.8/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.8/conv/conv.2/Conv ['/model/features/features.8/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_607', 'onnx::Conv_608']
# /model/features/features.8/Add ['/model/features/features.7/conv/conv.2/Conv_output_0', '/model/features/features.8/conv/conv.2/Conv_output_0']
# /model/features/features.9/conv/conv.0/conv.0.0/Conv ['/model/features/features.8/Add_output_0', 'onnx::Conv_610', 'onnx::Conv_611']
# /model/features/features.9/conv/conv.0/conv.0.2/Constant []
# /model/features/features.9/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.9/conv/conv.0/conv.0.2/Clip ['/model/features/features.9/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.9/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.9/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.9/conv/conv.1/conv.1.0/Conv ['/model/features/features.9/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_613', 'onnx::Conv_614']
# /model/features/features.9/conv/conv.1/conv.1.2/Constant []
# /model/features/features.9/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.9/conv/conv.1/conv.1.2/Clip ['/model/features/features.9/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.9/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.9/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.9/conv/conv.2/Conv ['/model/features/features.9/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_616', 'onnx::Conv_617']
# /model/features/features.9/Add ['/model/features/features.8/Add_output_0', '/model/features/features.9/conv/conv.2/Conv_output_0']
# /model/features/features.10/conv/conv.0/conv.0.0/Conv ['/model/features/features.9/Add_output_0', 'onnx::Conv_619', 'onnx::Conv_620']
# /model/features/features.10/conv/conv.0/conv.0.2/Constant []
# /model/features/features.10/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.10/conv/conv.0/conv.0.2/Clip ['/model/features/features.10/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.10/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.10/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.10/conv/conv.1/conv.1.0/Conv ['/model/features/features.10/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_622', 'onnx::Conv_623']
# /model/features/features.10/conv/conv.1/conv.1.2/Constant []
# /model/features/features.10/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.10/conv/conv.1/conv.1.2/Clip ['/model/features/features.10/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.10/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.10/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.10/conv/conv.2/Conv ['/model/features/features.10/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_625', 'onnx::Conv_626']
# /model/features/features.10/Add ['/model/features/features.9/Add_output_0', '/model/features/features.10/conv/conv.2/Conv_output_0']
# /model/features/features.11/conv/conv.0/conv.0.0/Conv ['/model/features/features.10/Add_output_0', 'onnx::Conv_628', 'onnx::Conv_629']
# /model/features/features.11/conv/conv.0/conv.0.2/Constant []
# /model/features/features.11/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.11/conv/conv.0/conv.0.2/Clip ['/model/features/features.11/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.11/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.11/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.11/conv/conv.1/conv.1.0/Conv ['/model/features/features.11/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_631', 'onnx::Conv_632']
# /model/features/features.11/conv/conv.1/conv.1.2/Constant []
# /model/features/features.11/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.11/conv/conv.1/conv.1.2/Clip ['/model/features/features.11/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.11/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.11/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.11/conv/conv.2/Conv ['/model/features/features.11/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_634', 'onnx::Conv_635']
# /model/features/features.12/conv/conv.0/conv.0.0/Conv ['/model/features/features.11/conv/conv.2/Conv_output_0', 'onnx::Conv_637', 'onnx::Conv_638']
# /model/features/features.12/conv/conv.0/conv.0.2/Constant []
# /model/features/features.12/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.12/conv/conv.0/conv.0.2/Clip ['/model/features/features.12/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.12/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.12/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.12/conv/conv.1/conv.1.0/Conv ['/model/features/features.12/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_640', 'onnx::Conv_641']
# /model/features/features.12/conv/conv.1/conv.1.2/Constant []
# /model/features/features.12/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.12/conv/conv.1/conv.1.2/Clip ['/model/features/features.12/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.12/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.12/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.12/conv/conv.2/Conv ['/model/features/features.12/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_643', 'onnx::Conv_644']
# /model/features/features.12/Add ['/model/features/features.11/conv/conv.2/Conv_output_0', '/model/features/features.12/conv/conv.2/Conv_output_0']
# /model/features/features.13/conv/conv.0/conv.0.0/Conv ['/model/features/features.12/Add_output_0', 'onnx::Conv_646', 'onnx::Conv_647']
# /model/features/features.13/conv/conv.0/conv.0.2/Constant []
# /model/features/features.13/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.13/conv/conv.0/conv.0.2/Clip ['/model/features/features.13/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.13/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.13/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.13/conv/conv.1/conv.1.0/Conv ['/model/features/features.13/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_649', 'onnx::Conv_650']
# /model/features/features.13/conv/conv.1/conv.1.2/Constant []
# /model/features/features.13/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.13/conv/conv.1/conv.1.2/Clip ['/model/features/features.13/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.13/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.13/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.13/conv/conv.2/Conv ['/model/features/features.13/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_652', 'onnx::Conv_653']
# /model/features/features.13/Add ['/model/features/features.12/Add_output_0', '/model/features/features.13/conv/conv.2/Conv_output_0']
# /model/features/features.14/conv/conv.0/conv.0.0/Conv ['/model/features/features.13/Add_output_0', 'onnx::Conv_655', 'onnx::Conv_656']
# /model/features/features.14/conv/conv.0/conv.0.2/Constant []
# /model/features/features.14/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.14/conv/conv.0/conv.0.2/Clip ['/model/features/features.14/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.14/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.14/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.14/conv/conv.1/conv.1.0/Conv ['/model/features/features.14/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_658', 'onnx::Conv_659']
# /model/features/features.14/conv/conv.1/conv.1.2/Constant []
# /model/features/features.14/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.14/conv/conv.1/conv.1.2/Clip ['/model/features/features.14/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.14/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.14/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.14/conv/conv.2/Conv ['/model/features/features.14/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_661', 'onnx::Conv_662']
# /model/features/features.15/conv/conv.0/conv.0.0/Conv ['/model/features/features.14/conv/conv.2/Conv_output_0', 'onnx::Conv_664', 'onnx::Conv_665']
# /model/features/features.15/conv/conv.0/conv.0.2/Constant []
# /model/features/features.15/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.15/conv/conv.0/conv.0.2/Clip ['/model/features/features.15/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.15/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.15/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.15/conv/conv.1/conv.1.0/Conv ['/model/features/features.15/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_667', 'onnx::Conv_668']
# /model/features/features.15/conv/conv.1/conv.1.2/Constant []
# /model/features/features.15/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.15/conv/conv.1/conv.1.2/Clip ['/model/features/features.15/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.15/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.15/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.15/conv/conv.2/Conv ['/model/features/features.15/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_670', 'onnx::Conv_671']
# /model/features/features.15/Add ['/model/features/features.14/conv/conv.2/Conv_output_0', '/model/features/features.15/conv/conv.2/Conv_output_0']
# /model/features/features.16/conv/conv.0/conv.0.0/Conv ['/model/features/features.15/Add_output_0', 'onnx::Conv_673', 'onnx::Conv_674']
# /model/features/features.16/conv/conv.0/conv.0.2/Constant []
# /model/features/features.16/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.16/conv/conv.0/conv.0.2/Clip ['/model/features/features.16/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.16/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.16/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.16/conv/conv.1/conv.1.0/Conv ['/model/features/features.16/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_676', 'onnx::Conv_677']
# /model/features/features.16/conv/conv.1/conv.1.2/Constant []
# /model/features/features.16/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.16/conv/conv.1/conv.1.2/Clip ['/model/features/features.16/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.16/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.16/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.16/conv/conv.2/Conv ['/model/features/features.16/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_679', 'onnx::Conv_680']
# /model/features/features.16/Add ['/model/features/features.15/Add_output_0', '/model/features/features.16/conv/conv.2/Conv_output_0']
# /model/features/features.17/conv/conv.0/conv.0.0/Conv ['/model/features/features.16/Add_output_0', 'onnx::Conv_682', 'onnx::Conv_683']
# /model/features/features.17/conv/conv.0/conv.0.2/Constant []
# /model/features/features.17/conv/conv.0/conv.0.2/Constant_1 []
# /model/features/features.17/conv/conv.0/conv.0.2/Clip ['/model/features/features.17/conv/conv.0/conv.0.0/Conv_output_0', '/model/features/features.17/conv/conv.0/conv.0.2/Constant_output_0', '/model/features/features.17/conv/conv.0/conv.0.2/Constant_1_output_0']
# /model/features/features.17/conv/conv.1/conv.1.0/Conv ['/model/features/features.17/conv/conv.0/conv.0.2/Clip_output_0', 'onnx::Conv_685', 'onnx::Conv_686']
# /model/features/features.17/conv/conv.1/conv.1.2/Constant []
# /model/features/features.17/conv/conv.1/conv.1.2/Constant_1 []
# /model/features/features.17/conv/conv.1/conv.1.2/Clip ['/model/features/features.17/conv/conv.1/conv.1.0/Conv_output_0', '/model/features/features.17/conv/conv.1/conv.1.2/Constant_output_0', '/model/features/features.17/conv/conv.1/conv.1.2/Constant_1_output_0']
# /model/features/features.17/conv/conv.2/Conv ['/model/features/features.17/conv/conv.1/conv.1.2/Clip_output_0', 'onnx::Conv_688', 'onnx::Conv_689']
# /model/features/features.18/features.18.0/Conv ['/model/features/features.17/conv/conv.2/Conv_output_0', 'onnx::Conv_691', 'onnx::Conv_692']
# /model/features/features.18/features.18.2/Constant []
# /model/features/features.18/features.18.2/Constant_1 []
# /model/features/features.18/features.18.2/Clip ['/model/features/features.18/features.18.0/Conv_output_0', '/model/features/features.18/features.18.2/Constant_output_0', '/model/features/features.18/features.18.2/Constant_1_output_0']
# /model/GlobalAveragePool ['/model/features/features.18/features.18.2/Clip_output_0']
# /model/Flatten ['/model/GlobalAveragePool_output_0']
# /model/classifier/classifier.1/Gemm ['/model/Flatten_output_0', 'model.classifier.1.weight', 'model.classifier.1.bias']

# %%
requires_grad = ["model.classifier.1.weight", "model.classifier.1.bias"]
frozen_params = [
   param.name
   for param in onnx_model.graph.initializer
   if param.name not in requires_grad
]


# Generate the training artifacts.
artifacts.generate_artifacts(
   onnx_model,
   requires_grad=requires_grad,
   frozen_params=frozen_params,
   loss=artifacts.LossType.CrossEntropyLoss,
   optimizer=artifacts.OptimType.AdamW,
   artifact_directory="training_artifacts"
)

# %%
import shutil

shutil.make_archive("training_artifacts", 'zip', "training_artifacts")
# Out:
# '/content/training_artifacts.zip'

# %%
from google.colab import files

files.download("training_artifacts.zip")
